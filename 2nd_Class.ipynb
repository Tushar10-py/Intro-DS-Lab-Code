# %% [markdown]
# <a href="https://colab.research.google.com/github/Tushar10-py/Intro-DS-Lab-Code/blob/main/2nd_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel("/content/2nd Class.xlsx")

# %%
df.head()
# Out:
#   Month  Fecebook View
# 0   Jan            250
# 1   Feb            500
# 2   Mar            750
# 3   Apr            850
# 4   May            950

# %%
df.tail()
# Out:
#   Month  Fecebook View
# 1   Feb            500
# 2   Mar            750
# 3   Apr            850
# 4   May            950
# 5  June           1100

# %%
df.columns
# Out:
# Index(['Month', 'Fecebook View'], dtype='object')

# %%
m = df['Month']
m
# Out:
# 0     Jan
# 1     Feb
# 2     Mar
# 3     Apr
# 4     May
# 5    June
# Name: Month, dtype: object

# %%
v = df['Fecebook View']
v
# Out:
# 0     250
# 1     500
# 2     750
# 3     850
# 4     950
# 5    1100
# Name: Fecebook View, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(m,v)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(m,v, color = "Orange")
plt.show()

# %%
import matplotlib.pyplot as plt
colors = ['red','green','blue','yellow','pink','Maroon','orange']
plt.bar(m,v, color=colors )
plt.show()

# %%
import matplotlib.pyplot as plt
colors = ['red','green','blue','yellow','pink','Maroon','orange']
plt.bar(m,v, color=colors )
plt.xlabel("Month")
plt.ylabel("View")
plt.title("Facebook Views")
plt.show()

# %%
plt.savefig('f.png')

# %%
plt.plot(m,v)

# %%
plt.pie(v)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f92b03c8950>,
# ...
#  [Text(1.0825223224767162, 0.19530852858904202, ''),
#   Text(0.831324497960876, 0.7203468463803375, ''),
#   Text(-0.03926153595185959, 1.099299109339538, ''),
#   Text(-1.0162675555991008, 0.4209516070008866, ''),
#   Text(-0.690215948880062, -0.8565056590073388, ''),
#   Text(0.7778177173879477, -0.7778172012223713, '')])
